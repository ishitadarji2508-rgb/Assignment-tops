# %% [markdown]
# 1. Write a short Python script that generates a random dataset of 10 users, each with two features: number of daily app opens and average session duration (in minutes). Print the dataset as a list of dictionaries.

# %%
import random

users = []

for i in range(1, 11):
    users.append({
        "user_id": i,
        "daily_app_opens": random.randint(1, 30),
        "avg_session_duration": round(random.uniform(2, 45), 2)
    })

print(users)
# Out:
# [{'user_id': 1, 'daily_app_opens': 16, 'avg_session_duration': 12.53}, {'user_id': 2, 'daily_app_opens': 21, 'avg_session_duration': 28.24}, {'user_id': 3, 'daily_app_opens': 19, 'avg_session_duration': 17.85}, {'user_id': 4, 'daily_app_opens': 9, 'avg_session_duration': 38.42}, {'user_id': 5, 'daily_app_opens': 30, 'avg_session_duration': 2.45}, {'user_id': 6, 'daily_app_opens': 22, 'avg_session_duration': 36.07}, {'user_id': 7, 'daily_app_opens': 18, 'avg_session_duration': 8.9}, {'user_id': 8, 'daily_app_opens': 4, 'avg_session_duration': 29.15}, {'user_id': 9, 'daily_app_opens': 14, 'avg_session_duration': 31.39}, {'user_id': 10, 'daily_app_opens': 5, 'avg_session_duration': 42.1}]

# %% [markdown]
# 2. Create a table comparing supervised and unsupervised learning in at least 4 points, using real-world app examples (like Instagram feed ranking for supervised, Spotify playlist grouping for unsupervised).

# %% [markdown]
# | Feature       | Supervised Learning                                        | Unsupervised Learning                                                   |
# | ------------- | ---------------------------------------------------------- | ----------------------------------------------------------------------- |
# | Training Data | Uses labeled data                                          | Uses unlabeled data                                                     |
# | Goal          | Predict labels or values                                   | Discover hidden patterns or groups                                      |
# | Output        | Classification or Regression                               | Clusters or Associations                                                |
# | Example       | Instagram feed ranking predicts whether you'll like a post | Spotify groups similar songs into playlists based on listening patterns |

# %% [markdown]
# 3. Given a list of 8 products with their price and number of reviews, use any method (even manual grouping) to segment them into 2-3 clusters based on similarity. Explain your reasoning for each cluster.<br><br><em><strong>Hint:</strong> Think about which products are similar in both price and popularity (reviews).</em>

# %% [markdown]
# | Product      | Price (₹) | Reviews |
# | ------------ | --------: | ------: |
# | Phone A      |     15000 |     500 |
# | Phone B      |     16000 |     450 |
# | Laptop A     |     60000 |     200 |
# | Laptop B     |     65000 |     180 |
# | Earbuds A    |      2000 |     900 |
# | Earbuds B    |      2200 |     850 |
# | Smartwatch A |      8000 |     350 |
# | Smartwatch B |      8500 |     300 |

# %% [markdown]
# Cluster 1: Budget & Highly Popular
# Earbuds A
# Earbuds B
#
# Reason: Low price and very high number of reviews.
#
# Cluster 2: Mid-Range Products
# Phone A
# Phone B
# Smartwatch A
# Smartwatch B
#
# Reason: Moderate price and moderate popularity.
#
# Cluster 3: Premium Products
# Laptop A
# Laptop B
#
# Reason: High price with comparatively fewer reviews

# %% [markdown]
# 4. List 3 scenarios in Zomato, Flipkart, or Spotify where unsupervised learning could be used to discover hidden patterns or group users/items. For each, briefly describe what data would be needed and what insights might be found.

# %% [markdown]
# 1. Zomato
#
# Data Needed
#
# Cuisine
# Ratings
# Cost
# Location
#
# Insight
#
# Group similar restaurants for personalized recommendations.
#
# 2. Flipkart
#
# Data Needed
#
# Purchase history
# Browsing history
# Cart items
#
# Insight
#
# Discover customer segments for targeted marketing.
#
# 3. Spotify
#
# Data Needed
#
# Tempo
# Energy
# Danceability
# Listening history
#
# Insight
#
# Automatically create playlists such as Workout, Chill, and Party.

# %% [markdown]
# 5. Find a real-world dataset (CSV or Excel) online that could be used for customer segmentation (for example, mall customers, e-commerce users, or music listeners). Share the link and describe the structure: how many features, what kind of data, and whether it’s labeled or unlabeled.<br><br><em><strong>Hint:</strong> Use Kaggle, UCI Machine Learning Repository, or Google to find your dataset.</em>

# %% [markdown]
# A popular dataset for clustering is the Mall Customers Dataset available on Kaggle.
#
# Dataset Link
#
# Mall Customers Dataset (Kaggle)
#
# Structure
# Rows: 200 customers
# Features: 5
# CustomerID
# Gender
# Age
# Annual Income (k$)
# Spending Score (1–100)
# Data Type:
# Numerical: CustomerID, Age, Annual Income, Spending Score
# Categorical: Gender
# Labels: None (unlabeled dataset), making it ideal for unsupervised learning tasks such as clustering.
