# %% [markdown]
# 1. Install TensorFlow and Keras in your Python environment, then create a new file called spotify_like_classifier.py.

# %% [markdown]
# pip install tensorflow

# %% [markdown]
# 2. In spotify_like_classifier.py, define a Sequential model in Keras with three Dense layers: the first with 16 units and 'relu' activation, the second with 8 units and 'relu', and the third with 1 unit and 'sigmoid' activation.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(16, activation='relu', input_shape=(2,)),
    layers.Dense(8, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

model.summary()
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │            48 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 193 (772.00 B)
#  Trainable params: 193 (772.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# 3. Compile your model using the 'adam' optimizer, 'binary_crossentropy' loss, and include 'accuracy' as a metric.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(16, activation='relu', input_shape=(2,)),
    layers.Dense(8, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 16)             │            48 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 193 (772.00 B)
#  Trainable params: 193 (772.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# 4. Simulate a small dataset: generate 100 random user profiles (features: listening_time, liked_genre_score) and a binary label (liked_song: 0 or 1). Train your model using model.fit() for 20 epochs and print the accuracy after training.<br><br><em><strong>Hint:</strong> Use numpy to generate random data for features and labels.</em>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(16, activation='relu', input_shape=(2,)),
    layers.Dense(8, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

np.random.seed(42)

listening_time = np.random.rand(100, 1) * 10
liked_genre_score = np.random.rand(100, 1) * 10

X = np.hstack([listening_time, liked_genre_score])

y = ((listening_time + liked_genre_score) > 10).astype(int)

model.fit(
    X,
    y,
    epochs=20,
    verbose=1
)

loss, acc = model.evaluate(X, y, verbose=0)

print("Final Accuracy:", acc)
print("Final Loss:", loss)
# Out:
# Epoch 1/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5200 - loss: 0.7020
# Epoch 2/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5100 - loss: 0.6929
# Epoch 3/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5100 - loss: 0.6848
# Epoch 4/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5100 - loss: 0.6790
# Epoch 5/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5100 - loss: 0.6715
# Epoch 6/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5100 - loss: 0.6654
# Epoch 7/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5100 - loss: 0.6593
# Epoch 8/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5100 - loss: 0.6550
# Epoch 9/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5100 - loss: 0.6507
# Epoch 10/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5200 - loss: 0.6472
# Epoch 11/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5200 - loss: 0.6445
# Epoch 12/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5200 - loss: 0.6421
# Epoch 13/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5200 - loss: 0.6398
# Epoch 14/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5200 - loss: 0.6374
# Epoch 15/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5200 - loss: 0.6355
# Epoch 16/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5300 - loss: 0.6338
# Epoch 17/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5300 - loss: 0.6322
# Epoch 18/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5300 - loss: 0.6308
# Epoch 19/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5300 - loss: 0.6291
# Epoch 20/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5300 - loss: 0.6277
# Final Accuracy: 0.5299999713897705
# Final Loss: 0.6265767812728882

# %% [markdown]
# 5. Add a callback to your fit() call that stops training early if the validation loss does not improve for 3 epochs.<br><br><em><strong>Hint:</strong> Use Keras' EarlyStopping callback and set patience=3.</em>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(16, activation='relu', input_shape=(2,)),
    layers.Dense(8, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

np.random.seed(42)

listening_time = np.random.rand(100, 1) * 10
liked_genre_score = np.random.rand(100, 1) * 10

X = np.hstack([listening_time, liked_genre_score])
y = ((listening_time + liked_genre_score) > 10).astype(int)

early_stop = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

model.fit(
    X,
    y,
    epochs=20,
    validation_split=0.2,
    callbacks=[early_stop],
    verbose=1
)

loss, acc = model.evaluate(X, y, verbose=0)

print("Final Accuracy:", acc)
print("Final Loss:", loss)
# Out:
# Epoch 1/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - accuracy: 0.5000 - loss: 0.8964 - val_accuracy: 0.5500 - val_loss: 0.8950
# Epoch 2/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.5000 - loss: 0.8211 - val_accuracy: 0.5500 - val_loss: 0.8176
# Epoch 3/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5000 - loss: 0.7562 - val_accuracy: 0.5500 - val_loss: 0.7490
# Epoch 4/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.5000 - loss: 0.6881 - val_accuracy: 0.5500 - val_loss: 0.6914
# Epoch 5/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.5000 - loss: 0.6450 - val_accuracy: 0.5500 - val_loss: 0.6455
# Epoch 6/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5125 - loss: 0.6073 - val_accuracy: 0.5500 - val_loss: 0.6129
# Epoch 7/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5750 - loss: 0.5892 - val_accuracy: 0.5500 - val_loss: 0.5924
# Epoch 8/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.5875 - loss: 0.5865 - val_accuracy: 0.6000 - val_loss: 0.5828
# Epoch 9/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.5750 - loss: 0.5763 - val_accuracy: 0.6000 - val_loss: 0.5796
# Epoch 10/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6500 - loss: 0.5812 - val_accuracy: 0.6000 - val_loss: 0.5783
# Epoch 11/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6625 - loss: 0.5822 - val_accuracy: 0.6000 - val_loss: 0.5759
# Epoch 12/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6625 - loss: 0.5806 - val_accuracy: 0.6000 - val_loss: 0.5727
# Epoch 13/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6500 - loss: 0.5771 - val_accuracy: 0.6000 - val_loss: 0.5694
# Epoch 14/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6625 - loss: 0.5722 - val_accuracy: 0.6000 - val_loss: 0.5666
# Epoch 15/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6750 - loss: 0.5684 - val_accuracy: 0.6000 - val_loss: 0.5654
# Epoch 16/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6625 - loss: 0.5640 - val_accuracy: 0.6000 - val_loss: 0.5655
# Epoch 17/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.6125 - loss: 0.5618 - val_accuracy: 0.6000 - val_loss: 0.5664
# Epoch 18/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6125 - loss: 0.5607 - val_accuracy: 0.6000 - val_loss: 0.5673
# Final Accuracy: 0.6499999761581421
# Final Loss: 0.565260112285614
