# %% [markdown]
# 1. Create a simple neural network using Keras to classify handwritten digits from the MNIST dataset, then experiment by changing the number of layers and neurons in your model to see how accuracy changes.<br><br><em><strong>Hint:</strong> Start with one hidden layer, then try adding another, and vary the number of neurons (e.g., 32, 64, 128).</em>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
model_1 = keras.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(32, activation='relu'),
    layers.Dense(10, activation='softmax')
])

model_1.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history_1 = model_1.fit(x_train, y_train, epochs=5, validation_data=(x_test, y_test))
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8992 - loss: 0.3594 - val_accuracy: 0.9305 - val_loss: 0.2294
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9453 - loss: 0.1923 - val_accuracy: 0.9460 - val_loss: 0.1762
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9557 - loss: 0.1511 - val_accuracy: 0.9562 - val_loss: 0.1499
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9622 - loss: 0.1269 - val_accuracy: 0.9588 - val_loss: 0.1352
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9675 - loss: 0.1110 - val_accuracy: 0.9630 - val_loss: 0.1302

# %%
model_2 = keras.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(10, activation='softmax')
])

model_2.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history_2 = model_2.fit(x_train, y_train, epochs=5, validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9114 - loss: 0.3067 - val_accuracy: 0.9478 - val_loss: 0.1754
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9584 - loss: 0.1417 - val_accuracy: 0.9605 - val_loss: 0.1283
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9686 - loss: 0.1048 - val_accuracy: 0.9654 - val_loss: 0.1093
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9737 - loss: 0.0836 - val_accuracy: 0.9671 - val_loss: 0.1048
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9788 - loss: 0.0684 - val_accuracy: 0.9714 - val_loss: 0.0939

# %%
model_3 = keras.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

model_3.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history_3 = model_3.fit(x_train, y_train, epochs=5, validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9282 - loss: 0.2564 - val_accuracy: 0.9617 - val_loss: 0.1291
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9676 - loss: 0.1116 - val_accuracy: 0.9699 - val_loss: 0.0960
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9773 - loss: 0.0770 - val_accuracy: 0.9742 - val_loss: 0.0854
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9827 - loss: 0.0566 - val_accuracy: 0.9773 - val_loss: 0.0757
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9863 - loss: 0.0453 - val_accuracy: 0.9761 - val_loss: 0.0761

# %% [markdown]
# 2. Train your MNIST model using different batch sizes (e.g., 16, 32, 64) and epochs (e.g., 5, 10, 20), and record how the training time and validation accuracy change for each combination.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import time

(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0


def create_model():
    model = keras.Sequential([
        layers.Flatten(input_shape=(28, 28)),
        layers.Dense(128, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model


batch_sizes = [16, 32, 64]
epoch_values = [5, 10, 20]

results = []

for batch in batch_sizes:
    for epochs in epoch_values:
        model = create_model()

        start = time.time()

        history = model.fit(
            x_train,
            y_train,
            validation_data=(x_test, y_test),
            epochs=epochs,
            batch_size=batch,
            verbose=0
        )

        end = time.time()

        val_acc = history.history['val_accuracy'][-1]
        train_time = end - start

        results.append((batch, epochs, train_time, val_acc))

        print(f"Batch={batch}, Epochs={epochs}, Time={train_time:.2f}s, Val Acc={val_acc:.4f}")
# Out:
# Batch=16, Epochs=5, Time=62.39s, Val Acc=0.9756
# Batch=16, Epochs=10, Time=134.63s, Val Acc=0.9799
# Batch=16, Epochs=20, Time=287.34s, Val Acc=0.9783
# Batch=32, Epochs=5, Time=34.45s, Val Acc=0.9768
# Batch=32, Epochs=10, Time=65.39s, Val Acc=0.9788
# Batch=32, Epochs=20, Time=136.95s, Val Acc=0.9779
# Batch=64, Epochs=5, Time=17.30s, Val Acc=0.9771
# Batch=64, Epochs=10, Time=37.52s, Val Acc=0.9779
# Batch=64, Epochs=20, Time=67.93s, Val Acc=0.9797

# %% [markdown]
# 3. Modify your Keras model to use three different optimizers (SGD, Adam, RMSprop) and compare the results by plotting training and validation loss for each optimizer.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
def create_model():
    model = keras.Sequential([
        layers.Flatten(input_shape=(28, 28)),
        layers.Dense(128, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])
    return model

# %%
optimizers = {
    "SGD": keras.optimizers.SGD(),
    "Adam": keras.optimizers.Adam(),
    "RMSprop": keras.optimizers.RMSprop()
}

histories = {}

# %%
for name, opt in optimizers.items():
    model = create_model()

    model.compile(
        optimizer=opt,
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    print(f"\nTraining with {name}...")

    history = model.fit(
        x_train,
        y_train,
        validation_data=(x_test, y_test),
        epochs=5,
        verbose=0
    )

    histories[name] = history
# Out:
# Training with SGD...
#
# Training with Adam...
#
# Training with RMSprop...

# %% [markdown]
# 4. Use KerasTuner to automatically search for the best number of neurons in the first hidden layer for your MNIST classifier. Show the code you used and report the best configuration found.<br><br><em><strong>Hint:</strong> Use Hyperband or RandomSearch from keras_tuner and set a reasonable search space for neurons (e.g., 32 to 256).</em>

# %%
pip install keras-tuner
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.8-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: keras in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from keras-tuner) (3.12.2)
# Requirement already satisfied: packaging in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from keras-tuner) (26.2)
# Requirement already satisfied: requests in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from keras-tuner) (2.34.2)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: grpcio in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from keras-tuner) (1.80.0)
# Requirement already satisfied: protobuf in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from keras-tuner) (7.34.1)
# Requirement already satisfied: typing-extensions~=4.12 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from grpcio->keras-tuner) (4.15.0)
# Requirement already satisfied: absl-py in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from keras->keras-tuner) (2.4.0)
# Requirement already satisfied: numpy in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from keras->keras-tuner) (2.2.6)
# Requirement already satisfied: rich in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from keras->keras-tuner) (15.0.0)
# Requirement already satisfied: namex in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from keras->keras-tuner) (0.1.0)
# Requirement already satisfied: h5py in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from keras->keras-tuner) (3.14.0)
# Requirement already satisfied: optree in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from keras->keras-tuner) (0.19.1)
# Requirement already satisfied: ml-dtypes in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from keras->keras-tuner) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from requests->keras-tuner) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from requests->keras-tuner) (3.15)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from requests->keras-tuner) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from requests->keras-tuner) (2026.4.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from rich->keras->keras-tuner) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from rich->keras->keras-tuner) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.2)
# Downloading keras_tuner-1.4.8-py3-none-any.whl (129 kB)
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras-tuner
#
#    ---------------------------------------- 0/2 [kt-legacy]
#    ---------------------------------------- 0/2 [kt-legacy]
#    -------------------- ------------------- 1/2 [keras-tuner]
#    -------------------- ------------------- 1/2 [keras-tuner]
#    -------------------- ------------------- 1/2 [keras-tuner]
#    -------------------- ------------------- 1/2 [keras-tuner]
#    -------------------- ------------------- 1/2 [keras-tuner]
#    -------------------- ------------------- 1/2 [keras-tuner]
#    -------------------- ------------------- 1/2 [keras-tuner]
#    -------------------- ------------------- 1/2 [keras-tuner]
#    -------------------- ------------------- 1/2 [keras-tuner]
#    ---------------------------------------- 2/2 [keras-tuner]
#
# Successfully installed keras-tuner-1.4.8 kt-legacy-1.0.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
import keras_tuner as kt

(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train / 255.0
X_test = X_test / 255.0

def build_model(hp):
    model = Sequential()

    model.add(Flatten(input_shape=(28, 28)))

    units = hp.Int(
        'units',
        min_value=32,
        max_value=256,
        step=32
    )

    model.add(Dense(units=units, activation='relu'))
    model.add(Dense(10, activation='softmax'))

    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

tuner = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=8,
    directory='mnist_tuning',
    project_name='neuron_search'
)

tuner.search(
    X_train,
    y_train,
    epochs=5,
    validation_split=0.2
)

best_hp = tuner.get_best_hyperparameters(num_trials=1)[0]

print("Best Number of Neurons:",
      best_hp.get('units'))

best_model = tuner.hypermodel.build(best_hp)

history = best_model.fit(
    X_train,
    y_train,
    epochs=10,
    validation_split=0.2
)

test_loss, test_acc = best_model.evaluate(X_test, y_test)
print("Test Accuracy:", test_acc)
# Out:
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras_tuner\src\engine\base_tuner.py", line 274, in _try_run_and_update_trial
#     self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras_tuner\src\engine\base_tuner.py", line 239, in _run_and_update_trial
#     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras_tuner\src\engine\tuner.py", line 309, in run_trial
#     self._configure_tensorboard_dir(callbacks, trial, execution)
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras_tuner\src\engine\tuner.py", line 421, in _configure_tensorboard_dir
#     from tensorboard.plugins.hparams import api as hparams_api
# ModuleNotFoundError: No module named 'tensorboard'
# Trial 2 Complete [00h 00m 00s]
#
# Best val_accuracy So Far: None
# Total elapsed time: 00h 00m 00s
#
# Search: Running Trial #3
#
# Value             |Best Value So Far |Hyperparameter
# 160               |64                |units
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 49
#      40 tuner = kt.RandomSearch(
#      41     build_model,
#      42     objective='val_accuracy',
#    (...)
#      45     project_name='neuron_search'
#      46 )
#      48 # Search for best hyperparameter
# ---> 49 tuner.search(
#      50     X_train,
#      51     y_train,
#      52     epochs=5,
#      53     validation_split=0.2
#      54 )
#      56 # Get best model and hyperparameters
#      57 best_hp = tuner.get_best_hyperparameters(num_trials=1)[0]
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras_tuner\src\engine\base_tuner.py:235, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     233     self.on_trial_begin(trial)
#     234     self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
# --> 235     self.on_trial_end(trial)
#     236 self.on_search_end()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras_tuner\src\engine\base_tuner.py:339, in BaseTuner.on_trial_end(self, trial)
#     333 def on_trial_end(self, trial):
#     334     """Called at the end of a trial.
#     335
#     336     Args:
#     337         trial: A `Trial` instance.
#     338     """
# --> 339     self.oracle.end_trial(trial)
#     340     self.save()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras_tuner\src\engine\oracle.py:108, in synchronized.<locals>.wrapped_func(*args, **kwargs)
#     106     LOCKS[oracle].acquire()
#     107     THREADS[oracle] = thread_name
# --> 108 ret_val = func(*args, **kwargs)
#     109 if need_acquire:
#     110     THREADS[oracle] = None
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras_tuner\src\engine\oracle.py:588, in Oracle.end_trial(self, trial)
#     586 if not self._retry(trial):
#     587     self.end_order.append(trial.trial_id)
# --> 588     self._check_consecutive_failures()
#     590 self._save_trial(trial)
#     591 self.save()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras_tuner\src\engine\oracle.py:545, in Oracle._check_consecutive_failures(self)
#     543     consecutive_failures = 0
#     544 if consecutive_failures == self.max_consecutive_failed_trials:
# --> 545     raise RuntimeError(
#     546         "Number of consecutive failures exceeded the limit "
#     547         f"of {self.max_consecutive_failed_trials}.\n"
#     548         + (trial.message or "")
#     549     )
#
# RuntimeError: Number of consecutive failures exceeded the limit of 3.
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras_tuner\src\engine\base_tuner.py", line 274, in _try_run_and_update_trial
#     self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras_tuner\src\engine\base_tuner.py", line 239, in _run_and_update_trial
#     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras_tuner\src\engine\tuner.py", line 309, in run_trial
#     self._configure_tensorboard_dir(callbacks, trial, execution)
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras_tuner\src\engine\tuner.py", line 421, in _configure_tensorboard_dir
#     from tensorboard.plugins.hparams import api as hparams_api
# ModuleNotFoundError: No module named 'tensorboard'

# %% [markdown]
# 5. Experiment with different weight initialization methods (e.g., 'he_normal', 'glorot_uniform', 'random_normal') in your Keras model and compare their impact on the model's training speed and accuracy.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import time

(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
def create_model(init):
    model = keras.Sequential([
        layers.Flatten(input_shape=(28, 28)),

        layers.Dense(128, activation='relu', kernel_initializer=init),
        layers.Dense(64, activation='relu', kernel_initializer=init),

        layers.Dense(10, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
initializers = {
    "he_normal": "he_normal",
    "glorot_uniform": "glorot_uniform",
    "random_normal": "random_normal"
}

results = []

for name, init in initializers.items():
    model = create_model(init)

    start = time.time()

    history = model.fit(
        x_train,
        y_train,
        epochs=5,
        validation_data=(x_test, y_test),
        verbose=0
    )

    end = time.time()

    final_acc = history.history['val_accuracy'][-1]
    train_time = end - start

    results.append((name, train_time, final_acc))

    print(f"{name} -> Time: {train_time:.2f}s | Val Accuracy: {final_acc:.4f}")
# Out:
# he_normal -> Time: 29.69s | Val Accuracy: 0.9771
# glorot_uniform -> Time: 30.95s | Val Accuracy: 0.9752
# random_normal -> Time: 29.88s | Val Accuracy: 0.9739
