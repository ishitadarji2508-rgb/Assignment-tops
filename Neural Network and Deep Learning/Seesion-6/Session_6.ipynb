# %% [markdown]
# 1. Create a Python script using NumPy to perform a manual forward pass for a single-layer neural network: given an input vector X and a weight matrix W, compute the dot product and apply the sigmoid activation function to get the output.

# %%
import numpy as np

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

X = np.array([0.5, 0.8, 0.2])

W = np.array([0.4, 0.6, 0.1])

z = np.dot(X, W)

output = sigmoid(z)

print("Input X:", X)
print("Weights W:", W)
print("Weighted Sum (z):", z)
print("Sigmoid Output:", output)
# Out:
# Input X: [0.5 0.8 0.2]
# Weights W: [0.4 0.6 0.1]
# Weighted Sum (z): 0.7
# Sigmoid Output: 0.6681877721681662

# %% [markdown]
# 2. Modify your script to handle a two-layer neural network: take an input vector, compute the first hidden layer's activations using a weight matrix and ReLU activation, then compute the output layer's activations using a second weight matrix and sigmoid activation.

# %%
import numpy as np

def relu(x):
    return np.maximum(0, x)

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

X = np.array([0.5, 0.8, 0.2])

W1 = np.array([
    [0.2, 0.4, 0.1],
    [0.5, 0.3, 0.2],
    [0.6, 0.1, 0.7]
])

W2 = np.array([0.4, 0.6, 0.3])

b1 = np.array([0.1, 0.1, 0.1])
b2 = 0.2

z1 = np.dot(X, W1) + b1
a1 = relu(z1)

z2 = np.dot(a1, W2) + b2
output = sigmoid(z2)

print("Hidden layer output:", a1)
print("Final output:", output)
# Out:
# Hidden layer output: [0.72 0.56 0.45]
# Final output: 0.7229215437983317

# %% [markdown]
# 3. Visualize the activations of each layer in your two-layer network using matplotlib — plot the input, hidden, and output activations as bar charts to show how data transforms through the network.<br><br><em><strong>Hint:</strong> Use plt.bar() for each layer and display them in separate subplots.</em>

# %%
import numpy as np
import matplotlib.pyplot as plt

def relu(x):
    return np.maximum(0, x)

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

X = np.array([0.5, 0.8, 0.2])


W1 = np.array([
    [0.2, 0.4, 0.1],
    [0.5, 0.3, 0.2],
    [0.6, 0.1, 0.7]
])
b1 = np.array([0.1, 0.1, 0.1])

W2 = np.array([0.4, 0.6, 0.3])
b2 = 0.2

z1 = np.dot(X, W1) + b1
a1 = relu(z1)

z2 = np.dot(a1, W2) + b2
a2 = sigmoid(z2)

print("Input:", X)
print("Hidden activations:", a1)
print("Output:", a2)


fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].bar(range(len(X)), X)
axes[0].set_title("Input Layer")
axes[0].set_xticks(range(len(X)))

axes[1].bar(range(len(a1)), a1)
axes[1].set_title("Hidden Layer (ReLU)")
axes[1].set_xticks(range(len(a1)))


axes[2].bar([0], [a2])
axes[2].set_title("Output Layer (Sigmoid)")
axes[2].set_xticks([0])

plt.tight_layout()
plt.show()
# Out:
# Input: [0.5 0.8 0.2]
# Hidden activations: [0.72 0.56 0.45]
# Output: 0.7229215437983317

# %% [markdown]
# 4. Given a set of random weights and a batch of three input vectors, perform a forward pass through a three-layer network (input, one hidden, output) and print the output activations for each input.<br><br><em><strong>Constraint:</strong> Use only NumPy for all matrix operations and activations.</em>

# %%
import numpy as np


def relu(x):
    return np.maximum(0, x)

def sigmoid(x):
    return 1 / (1 + np.exp(-x))


X = np.array([
    [0.5, 0.2, 0.1],
    [0.9, 0.4, 0.3],
    [0.3, 0.7, 0.8]
])

np.random.seed(42)

W1 = np.random.randn(3, 4)   
b1 = np.random.randn(4)

W2 = np.random.randn(4, 1)   
b2 = np.random.randn(1)


Z1 = np.dot(X, W1) + b1
A1 = relu(Z1)

Z2 = np.dot(A1, W2) + b2
A2 = sigmoid(Z2)


for i in range(len(X)):
    print(f"\nInput {i+1}: {X[i]}")
    print(f"Hidden Activation: {A1[i]}")
    print(f"Output Activation: {A2[i][0]:.4f}")
# Out:
# Input 1: [0.5 0.2 0.1]
# Hidden Activation: [0.39654123 0.         0.         0.30614137]
# Output Activation: 0.6529
#
# Input 2: [0.9 0.4 0.3]
# Hidden Activation: [0.45450134 0.         0.         0.97569431]
# Output Activation: 0.4079
#
# Input 3: [0.3 0.7 0.8]
# Hidden Activation: [0.         0.         0.         0.05924194]
# Output Activation: 0.7993
