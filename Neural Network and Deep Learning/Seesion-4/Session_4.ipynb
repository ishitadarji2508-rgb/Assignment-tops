# %% [markdown]
# 1. Write Python functions for the sigmoid, tanh, and ReLU activation functions that take a single float as input and return the output value.

# %%
import numpy as np

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def tanh(x):
    return np.tanh(x)

def relu(x):
    return max(0, x)

print("Sigmoid(2):", sigmoid(2))
print("Tanh(2):", tanh(2))
print("ReLU(2):", relu(2))
# Out:
# Sigmoid(2): 0.8807970779778823
# Tanh(2): 0.9640275800758169
# ReLU(2): 2

# %% [markdown]
# 2. Use matplotlib to plot the graphs of sigmoid, tanh, and ReLU functions on the same figure for input values ranging from -10 to 10.<br><br><em><strong>Hint:</strong> Use numpy to generate input values and label each curve clearly.</em>

# %%
import numpy as np
import matplotlib.pyplot as plt

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def tanh(x):
    return np.tanh(x)

def relu(x):
    return np.maximum(0, x)

x = np.linspace(-10, 10, 500)

plt.figure(figsize=(8, 5))
plt.plot(x, sigmoid(x), label="Sigmoid")
plt.plot(x, tanh(x), label="Tanh")
plt.plot(x, relu(x), label="ReLU")

plt.title("Activation Functions")
plt.xlabel("Input")
plt.ylabel("Output")
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# 3. Simulate the vanishing gradient problem by calculating and printing the derivative of the sigmoid function for input values between -10 and 10. Observe and explain where the gradient becomes very small.

# %%
import numpy as np

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_derivative(x):
    s = sigmoid(x)
    return s * (1 - s)

values = np.arange(-10, 11)

print("x\tDerivative")

for x in values:
    print(f"{x}\t{sigmoid_derivative(x):.6f}")
# Out:
# x	Derivative
# -10	0.000045
# -9	0.000123
# -8	0.000335
# -7	0.000910
# -6	0.002467
# -5	0.006648
# -4	0.017663
# -3	0.045177
# -2	0.104994
# -1	0.196612
# 0	0.250000
# 1	0.196612
# 2	0.104994
# 3	0.045177
# 4	0.017663
# 5	0.006648
# 6	0.002467
# 7	0.000910
# 8	0.000335
# 9	0.000123
# 10	0.000045

# %% [markdown]
# 4. Create a function that demonstrates the 'dying ReLU' problem by passing an array of negative values through the ReLU function and showing the output.<br><br><em><strong>Hint:</strong> Print both the input and output arrays to highlight the effect.</em>

# %%
import numpy as np

def relu(x):
    return np.maximum(0, x)

negative_values = np.array([-10, -8, -5, -3, -1])

outputs = relu(negative_values)

print("Input Array : ", negative_values)
print("Output Array:", outputs)
# Out:
# Input Array :  [-10  -8  -5  -3  -1]
# Output Array: [0 0 0 0 0]

# %% [markdown]
# 5. Pick any activation function (sigmoid, tanh, or ReLU) and modify its Python implementation to add a parameter that scales the input (e.g., f(x) = sigmoid(a*x) where 'a' is a new parameter). Plot and compare the original and modified activation functions using matplotlib.

# %%
import numpy as np
import matplotlib.pyplot as plt

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def scaled_sigmoid(x, a):
    return 1 / (1 + np.exp(-a * x))

x = np.linspace(-10, 10, 500)

original = sigmoid(x)
modified = scaled_sigmoid(x, a=2)

plt.figure(figsize=(8, 5))
plt.plot(x, original, label="Original Sigmoid (a=1)")
plt.plot(x, modified, label="Scaled Sigmoid (a=2)")

plt.title("Comparison of Original and Scaled Sigmoid")
plt.xlabel("Input (x)")
plt.ylabel("Output")
plt.legend()
plt.grid(True)

plt.show()
